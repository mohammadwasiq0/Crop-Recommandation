# %% [markdown]
# <center> <h1> Agriculture : Crop Prediction </h1> </center>
#
# ![image](https://static.farmtario.com/wp-content/uploads/2020/11/10163516/digital_agriculture_graphic_1163941571_cmyk.jpg)
#
# ## About Me:
# ### Name: Mohammad Wasiq
# ### Education: B.Sc.(Statistics) and M.Sc.(Data Science)
# ### Connect with Me on
# ### [**E-mail**](mohammadwasiqturk@gmail.com), [**LinkedIn**](https://www.linkedin.com/in/mohammadwasiq0/), [**GitHub**](https://github.com/mohammadwasiq0), [**Twitter**](https://twitter.com/Mohammadwasiq0)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from ipywidgets import interact
import warnings
warnings.filterwarnings('ignore')

# %%
data= pd.read_csv("Crop_recommendation.csv")
print(data.shape)
display(data.head(2))
# Out:
# (2200, 8)
#     N   P   K  temperature  humidity   ph  rainfall label
# 0  90  42  43        20.88     82.00 6.50    202.94  rice
# 1  85  58  41        21.77     80.32 7.04    226.66  rice

# %%
data.dtypes
# Out:
# N                int64
# P                int64
# K                int64
# temperature    float64
# humidity       float64
# ph             float64
# rainfall       float64
# label           object
# dtype: object

# %%
data.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
# Unique values of label columns
data['label'].unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
data['label'].value_counts(dropna=False)
# Out:
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: label, dtype: int64

# %%
data.columns
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label'], dtype='object')

# %%
# Lets check the Sataistics of each crop

@interact
def summay(crops= list(data['label'].value_counts().index)):
    x= data[data['label']==crops]
    
    print("="*50)
    print("Statistics for Nitrogen")
    print("Minimum Nitrogen Required :", x['N'].min())
    print("Mean Nitrogen Required :", x['N'].mean())
    print("Maximum Nitrogen Required :", x['N'].max())

    print("="*50)
    print("Statistics for Phosphorous")
    print("Minimum Phosphorous Required :", x['P'].min())
    print("Mean Phosphorous Required :", x['P'].mean())
    print("Maximum Phosphorous Required :", x['P'].max())    
    
    print("="*50)
    print("Statistics for Potassium")
    print("Minimum Potassium Required :", x['K'].min())
    print("Mean Potassium Required :", x['K'].mean())
    print("Maximum Potassium Required :", x['K'].max())
    
    print("="*50)
    print("Statistics for Temperature")
    print("Minimum Temperature Required : {0:0.2f}".format(x['temperature'].min()))
    print("Mean Temperature Required : {0:0.2f}".format(x['temperature'].mean()))
    print("Maximum Temperature Required : {0:0.2f}".format(x['temperature'].max()))
    
    print("="*50)
    print("Statistics for Humidity")
    print("Minimum Humidity Required : {0:0.2f}".format(x['humidity'].min()))
    print("Mean Humidity Required : {0:0.2f}".format(x['humidity'].mean()))
    print("Maximum Humidity Required : {0:0.2f}".format(x['humidity'].max()))
    
    print("="*50)
    print("Statistics for PH")
    print("Minimum PH Required : {0:0.2f}".format(x['ph'].min()))
    print("Mean PH Required : {0:0.2f}".format(x['ph'].mean()))
    print("Maximum PH Required : {0:0.2f}".format(x['ph'].max()))
    
    print("="*50)
    print("Statistics for Rainfall")
    print("Minimum Rainfall Required : {0:0.2f}".format(x['rainfall'].min()))
    print("Mean Rainfall Required : {0:0.2f}".format(x['rainfall'].mean()))
    print("Maximum Rainfall Required : {0:0.2f}".format(x['rainfall'].max()))
# Out:
# interactive(children=(Dropdown(description='crops', options=('rice', 'maize', 'jute', 'cotton', 'coconut', 'pa…

# %%
column_names = {
    'N': 'Nitrogen',
    'P': 'Phosphorous',
    'K': 'Potassium',
    'temperature': 'Temperature',
    'humidity': 'Humidity',
    'ph': 'PH',
    'rainfall': 'Rainfall'
}

@interact
def summary(crops=list(data['label'].value_counts().index)):
    columns = ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']

    print("=" * 50)

    for column in columns:
        full_column_name = column_names.get(column, column.capitalize())
        print(f"Statistics for {full_column_name}")
        print(f"Minimum {full_column_name} Required: {data[data['label'] == crops][column].min()}")
        print(f"Mean {full_column_name} Required: {data[data['label'] == crops][column].mean()}")
        print(f"Maximum {full_column_name} Required: {data[data['label'] == crops][column].max()}")
        print("=" * 50)
# Out:
# interactive(children=(Dropdown(description='crops', options=('rice', 'maize', 'jute', 'cotton', 'coconut', 'pa…

# %%
@interact

def compare(conditions= ['N', 'P', 'K', 'temperature' , 'ph', 'humidity', 'rainfall']):
    print("Average Value for", conditions, "is {0:.2f}".format(data[conditions].mean()))
    print('='*50)
    
    unique_label= data['label'].unique()
    for name in unique_label:     
        print(f"{name} : ", "{0:.2f}".format(data[data['label']==name][conditions].mean()))
# Out:
# Average Value for N is 50.55
# ...
# rice :  79.89
# maize :  77.76
# chickpea :  40.09
# kidneybeans :  20.75
# pigeonpeas :  20.73
# mothbeans :  21.44
# mungbean :  20.99
# blackgram :  40.02
# lentil :  18.77
# pomegranate :  18.87
# banana :  100.23
# mango :  20.07
# grapes :  23.18
# watermelon :  99.42
# muskmelon :  100.32
# apple :  20.80
# orange :  19.58
# papaya :  49.88
# coconut :  21.98
# cotton :  117.77
# jute :  78.40
# coffee :  101.20
# interactive(children=(Dropdown(description='conditions', options=('N', 'P', 'K', 'temperature', 'ph', 'humidit…

# %%
# Same as above
@interact

def compare(conditions= ['N', 'P', 'K', 'temperature' , 'ph', 'humidity', 'rainfall']):
    print("Average Value for", conditions, "is {0:.2f}".format(data[conditions].mean()))
    print('='*50)
    
    unique_labels = data['label'].unique()
    for label in unique_labels:
        label_df = data[data['label'] == label]
        print(f"{label.capitalize()} : ", end="")
        for condition in conditions:
            print("{0:.2f}".format(label_df[condition].mean()))
# Out:
# interactive(children=(Dropdown(description='conditions', options=('N', 'P', 'K', 'temperature', 'ph', 'humidit…

# %%
# For graeter than Average

@interact
def compare(conditions= ['N', 'P', 'K', 'temperature' , 'ph', 'humidity', 'rainfall']):
    print("Crops which require greater than average", conditions, '\n' )
    print(data[data[conditions] > data[conditions].mean()]['label'].unique())
    print("="*50)
    print("Crops which require less than average", conditions, '\n')
    print(data[data[conditions] <= data[conditions].mean()]['label'].unique())
# Out:
# interactive(children=(Dropdown(description='conditions', options=('N', 'P', 'K', 'temperature', 'ph', 'humidit…

# %%
data.shape
# Out:
# (2200, 8)

# %%
for col in data.columns[0:6]:
    sns.distplot(data[col], color= 'red')
    plt.xlabel(col, fontsize= 12)
    plt.grid()
    plt.show()

# %%
# Set up subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15, 10))
fig.suptitle('Distribution Plots', fontsize=16)

# Flatten the 2D array of subplots to simplify indexing
axes = axes.flatten()

# Iterate through columns and plot
for i, col in enumerate(data.columns[0:6]):
    sns.distplot(data[col], color='red', ax=axes[i])
    axes[i].set_title(col, fontsize=12)
    axes[i].grid()

plt.tight_layout(rect=[0, 0, 1, 0.96])  # Adjust layout for suptitle
plt.show()

# %%
## Lets find out some Interesting Facts
print("Some Interesting Patterns")


print("Crops which requires very High Ratio of Nitrogen Content in Soil: ", data[data['N'] > 120]['label'].unique())
print()
print("Crops which requires very Low Ratio of Nitrogen Content in Soil: ", data[data['N'] < 120]['label'].unique())
print("="*125)
print()

print("Crops which requires very High Ratio of Phosphorous Content in Soil: ", data[data['P'] > 100]['label'].unique())
print()
print("Crops which requires very Low Ratio of Phosphorous Content in Soil: ", data[data['P'] < 100]['label'].unique())
print("="*125)
print()

print("Crops which requires very High Ratio of Potassium Content in Soil: ", data[data['K'] > 200]['label'].unique())
print()
print("Crops which requires very Low Ratio of Potassium Content in Soil: ", data[data['K'] < 200]['label'].unique())
print("="*125)
print()

print("Crops which requires very High Rainfall : ", data[data['rainfall'] > 200]['label'].unique())
print()
print("Crops which requires very Low Rainfall : ", data[data['rainfall'] < 200]['label'].unique())
print("="*125)
print()

print("Crops which requires very High Temperature : ", data[data['temperature'] > 40]['label'].unique())
print()
print("Crops which requires very Low Temperature : ", data[data['temperature'] < 10]['label'].unique())
print("="*125)
print()

print("Crops which requires very High Humidity : ", data[data['humidity'] > 20]['label'].unique())
print()
print("Crops which requires very Low Humidity : ", data[data['humidity'] < 20]['label'].unique())
print("="*125)
print()

print("Crops which requires very High pH : ", data[data['ph'] > 9]['label'].unique())
print()
print("Crops which requires very Low pH : ", data[data['ph'] < 4]['label'].unique())
# Out:
# Some Interesting Patterns
# Crops which requires very High Ratio of Nitrogen Content in Soil:  ['cotton']
#
# Crops which requires very Low Ratio of Nitrogen Content in Soil:  ['rice' 'maize' 'chickpea' 'kidneybeans' 'pigeonpeas' 'mothbeans'
#  'mungbean' 'blackgram' 'lentil' 'pomegranate' 'banana' 'mango' 'grapes'
#  'watermelon' 'muskmelon' 'apple' 'orange' 'papaya' 'coconut' 'cotton'
#  'jute' 'coffee']
# ...
#
# Crops which requires very High Ratio of Phosphorous Content in Soil:  ['grapes' 'apple']
#
# Crops which requires very Low Ratio of Phosphorous Content in Soil:  ['rice' 'maize' 'chickpea' 'kidneybeans' 'pigeonpeas' 'mothbeans'
#  'mungbean' 'blackgram' 'lentil' 'pomegranate' 'banana' 'mango'
#  'watermelon' 'muskmelon' 'orange' 'papaya' 'coconut' 'cotton' 'jute'
#  'coffee']
# ...
#
# Crops which requires very High Ratio of Potassium Content in Soil:  ['grapes' 'apple']
#
# ...

# %%
# Crops according to the Season
print("Summer Crops")

print(data[(data['temperature']>30) & (data['humidity']>50)]['label'].unique())
print('='*100)
print()

print("Winter Crops")
print(data[(data['temperature']<20) & (data['humidity']>30)]['label'].unique())
print('='*100)
print()

print("Rainy Crops")
print(data[(data['rainfall']>200) & (data['humidity']>30)]['label'].unique())
print('='*100)
print()
# Out:
# Summer Crops
# ['pigeonpeas' 'mothbeans' 'blackgram' 'mango' 'grapes' 'orange' 'papaya']
# ...
#
# Winter Crops
# ['maize' 'pigeonpeas' 'lentil' 'pomegranate' 'grapes' 'orange']
# ...
#
# Rainy Crops
# ['rice' 'papaya' 'coconut']
# ...

# %%
from sklearn.cluster import KMeans

# Remove the labels column
X= data.drop(['label'], axis=1)
y= data['label']
print(X.shape, y.shape)
# Out:
# (2200, 7) (2200,)

# %%
# Elbow Plot

plt.rcParams['figure.figsize']= (10, 4)

wcss= []
for i in range(1, 11):
    km= KMeans(n_clusters=i, init='k-means++', max_iter=300,
              n_init=10, random_state=0)
    km.fit(X)
    wcss.append(km.inertia_)
    
wcss
# Out:
# [18820170.463645916,
#  12070916.353533491,
#  7423970.865410905,
#  5337358.5607463885,
#  4417511.116768206,
#  3748642.3531599217,
#  3103936.6816232046,
#  2727858.0937568434,
#  2374253.7424763488,
#  2130935.162281194]

# %%
# Plot the results
plt.plot(range(1, 11), wcss)
plt.title("Elbow Plot Method", fontsize=20)
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.ticklabel_format(style='plain', axis='y')
plt.xticks(range(1, 11))
plt.show()

# %%
# Let's implemente the KMeans algorithm to perform Clustering Analysis
km1= KMeans(n_clusters=4, init='k-means++', max_iter=300,
              n_init=10, random_state=0)
y_means= km1.fit_predict(X)

# Results
y_means= pd.DataFrame(y_means)
z= pd.concat([y_means, y], axis=1, ignore_index=True)

print(z.shape)
z.head(2)
# Out:
# (2200, 2)
#    0     1
# 0  3  rice
# 1  3  rice

# %%
z.columns= ['cluster', 'label']
z.head(2)
# Out:
#    cluster label
# 0        3  rice
# 1        3  rice

# %%
z['cluster'].unique()
# Out:
# array([3, 2, 1, 0])

# %%
# Let's check the Clusters of each Crops
for i in range(0, 4):
    print(f"Crops in {i} Cluster : ", z[z['cluster']==i]['label'].unique())
    print("="*100)
    print()
# Out:
# Crops in 0 Cluster :  ['grapes' 'apple']
# ...
#
# Crops in 1 Cluster :  ['maize' 'chickpea' 'kidneybeans' 'pigeonpeas' 'mothbeans' 'mungbean'
#  'blackgram' 'lentil' 'pomegranate' 'mango' 'orange' 'papaya' 'coconut']
# ...
#
# Crops in 2 Cluster :  ['maize' 'banana' 'watermelon' 'muskmelon' 'papaya' 'cotton' 'coffee']
# ...
#
# Crops in 3 Cluster :  ['rice' 'pigeonpeas' 'papaya' 'coconut' 'jute' 'coffee']
# ...

# %%
print(X.shape, y.shape)
# Out:
# (2200, 7) (2200,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test= train_test_split(X, y,
                                                  test_size=0.2,
                                                  random_state=0)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (1760, 7) (440, 7) (1760,) (440,)

# %%
from sklearn.linear_model import LogisticRegression

model= LogisticRegression()
model.fit(X_train, y_train)
y_pred= model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report

# Plot the comfusion matrix
plt.rcParams['figure.figsize']= (10, 10)
cm= confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, cmap='Wistia')
plt.title("Confusion Martix for Logistic Regression", fontsize= 15)
plt.show()

# %%
cr= classification_report(y_test, y_pred)

data = []

for line in lines[0:22]: 
    row = line.split()
    data.append(row)

# Create a DataFrame
columns = ['class'] + data[0][:-1] + ['support']
report = pd.DataFrame(data, columns=columns)
report.set_index('class', inplace=True)

# Convert strings to numeric values
report = report.apply(pd.to_numeric, errors='ignore')

# Display the DataFrame
report= report.T
report= report.drop(columns=['precision', None], axis=1)
report
# Out:
# class     apple banana blackgram chickpea coconut coffee cotton grapes  jute  \
# precision  1.00   1.00      0.86     1.00    1.00   1.00   0.89   1.00  0.84
# recall     1.00   1.00      0.82     1.00    1.00   1.00   1.00   1.00  1.00
# f1-score   1.00   1.00      0.84     1.00    1.00   1.00   0.94   1.00  0.91
# support   18.00  18.00     22.00    23.00   15.00  17.00  16.00  18.00 21.00
#
# class     kidneybeans lentil maize mango mothbeans mungbean muskmelon orange  \
# precision        1.00   0.94  0.94  1.00      0.88     1.00      1.00   1.00
# recall           1.00   0.94  0.89  1.00      0.92     1.00      1.00   1.00
# f1-score         1.00   0.94  0.91  1.00      0.90     1.00      1.00   1.00
# support         20.00  17.00 18.00 21.00     25.00    17.00     23.00  23.00
#
# class     papaya pigeonpeas pomegranate
# precision   1.00       1.00        1.00
# recall      0.95       1.00        1.00
# f1-score    0.98       1.00        1.00
# ...

# %%
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        18
#       banana       1.00      1.00      1.00        18
#    blackgram       0.86      0.82      0.84        22
#     chickpea       1.00      1.00      1.00        23
#      coconut       1.00      1.00      1.00        15
#       coffee       1.00      1.00      1.00        17
#       cotton       0.89      1.00      0.94        16
#       grapes       1.00      1.00      1.00        18
#         jute       0.84      1.00      0.91        21
#  kidneybeans       1.00      1.00      1.00        20
#       lentil       0.94      0.94      0.94        17
#        maize       0.94      0.89      0.91        18
#        mango       1.00      1.00      1.00        21
#    mothbeans       0.88      0.92      0.90        25
#     mungbean       1.00      1.00      1.00        17
#    muskmelon       1.00      1.00      1.00        23
# ...

# %%
prediction= model.predict((np.array([[90, 
                                      40, 
                                      40, 
                                      20, 
                                      80, 
                                      7, 
                                      200]])))

print("Crop for these Climatic Conditions is :", prediction)
# Out:
# Crop for these Climatic Conditions is : ['rice']

# %% [markdown]
# <center> <h1> Project END </h1> </center>
#
# I take help from this [**YouTube Video**](https://youtu.be/YAwiLoY8i-s?si=ob-MSuwkQKh7toc-) for Reference.
